# %%
sum(tuole)function
# Out:
#   File "<ipython-input-1-43d4a0a57dd9>", line 1
#     sum(tuole)function
#               ^
# SyntaxError: invalid syntax

# %%
my_set = {1,2,3,4,5}
my_set.clear()
print(len(my_set))
# Out:
# 0

# %%
if temperature <90:
  go to the park
else:
  stay inside and play vidio game

# %%
temp = input("Enter temperature")
if int(temp)>90:
  print("stay inside and play vidio game")
else:
  print("go to parl")
# Out:
# Enter temperature85
# go to parl

# %%
age = int(input())
if age >=18:
  print("you are an adult")
# Out:
# 65
# you are an adult

# %%
speed = int(input())
if speed >50:
  print("slow down")
# Out:
# 40

# %%
age = 20
if age >=18:
  print("welcome")
# Out:
# welcome

# %%
age = int(input())
if age>=18:
  print("welcome to the club")
else:
  print("you are not allowed inside")
# Out:
# 15
# you are not allowed inside

# %%
age = int(input())
if ((age>=18) and (age<60)or(age==90)):
  print("welcome to the club!")
else:
  print("you are noy allowed inside")
# Out:
# 90
# welcome to the club!

# %%
score = 75
if score>=60:
  print("congratulation")
# Out:
# congratulation

# %%
age = int(input())
if age >=18:
  print("you are an adult")
elif age>=13:
  print("you are an teenager")
else:
  print("you are a child")
# Out:
# 20
# you are an adult

# %%
age = int(input("how old are you"))
if age <5:
  price = 0
elif age <=12:
  price = 50
elif age<=64:
  price = 100
else:
  price = 70

# %%
age = int(input("Enter your age:"))
height = int(input("Enter your height in cm:"))
if age >=10:
  print("you are old enough to ride the rollercoaster")
if height>=120:
  print("and you need the height requiredment.")
else:
  print("you are not aligible to ride the rollercoaster because you are too young")
# Out:
# Enter your age:18
# Enter your height in cm:120
# you are old enough to ride the rollercoaster
# and you need the height requiredment.
